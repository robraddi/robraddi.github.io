# %% [markdown]
# <h1 style="align: center;font-size: 16pt;"> Robert M. Raddi</h1>
# <h1 style="align: center;font-size: 12pt;"> Graduate Research Assistant in the Voelz lab at Temple University Philadelphia, Pennsylvania</h1>
# <h1 style="align: center;font-size: 10pt;">Phone: 267-312-0604; Email: <a href="rraddi@temple.edu"> rraddi@temple.edu</a>; Website: <a href="rraddi@temple.edu">robraddi.github.io</a>;  Github: <a href="github.com/robraddi">github.com/robraddi</a></h1>
#
# <hr style="height:2.5px">
#
# <!-- Summary -->
# <h3 style="align: left;font-size: 12pt;"> Summary </h3>
# <ul>
#     <li style="list-style-type: none;font-size: 10pt;">Proficient in various programming languages & packaging modules</li>
#     <li style="list-style-type: none;font-size: 10pt">Constructed simulation code from scratch (MCMC & MD) as toy models</li>
#     <li style="list-style-type: none;font-size: 10pt">Strong statistical modeling (Bayesian Inference, Markov state models) & data analysis skills</li>
#     <li style="list-style-type: none;font-size: 10pt">Research experience in binding mechanisms of proteins</li>
#     <li style="list-style-type: none;font-size: 10pt">Experience using high-performance computing clusters</li>
# </ul>
#
# <hr style="height:2.5px">
#
# <!-- Education -->
# <h3 style="align: left;font-size: 12pt;">Education</h3>
# <h4 style="align: left;font-size: 10pt;">2018 - 2023 &nbsp;&nbsp;&nbsp;&nbsp; Ph.D. Theoretical/Physical Chemistry, Temple University; &nbsp;&nbsp;&nbsp;&nbsp;Principal Investigator: Dr. Vincent Voelz
# </h4>
# <h4 style="align: left;font-size: 10pt;">2013 - 2017 &nbsp;&nbsp;&nbsp;&nbsp; B.S. Chemistry, Temple University &nbsp;&nbsp;&nbsp;&nbsp; <a href="images/ACS.jpg" target="_blank">ACS Certification</a>;</h4>
#
# <hr style="height:2.5px">
#
# <!-- History/Experience -->
# <h3 style="align: left;font-size: 12pt;"> History/Experience </h3>
# <h3 style="align: left;font-size: 10pt;">
#     2019 - Present &nbsp;&nbsp;&nbsp;&nbsp; Graduate Research Assistant, Temple University
#     <ul>
#         <li style="list-style-type: none;font-size: 10pt;font-weight: normal;">Development of BICePs 2.0 </li>
#         <li style="list-style-type: none;font-size: 10pt;font-weight: normal;"><a href="images/THE.jpg" target="_blank">Teaching in Higher Education Certification</a>;</li>
#     </ul>
#     June 2019 - June 2019 &nbsp;&nbsp;&nbsp;&nbsp; Academic Intern for Computing & Statistics Workshop, Temple University
#     <ul>
#         <li style="list-style-type: none;font-size: 10pt;font-weight: normal;">This 2-week graduate level summer workshop of ~30 students was organized by Matthew Newby (Physics), Vincent Voelz (Chemistry) and Adrienn Ruzsinszky (Physics).  I contributed to some lecture material (slides), helped students one-on-one and answered various questions regarding Python, Bash, Jupyter Notebooks, GitHub, etc. (basic programming fundamentals). Website: <a href="sites.temple.edu/compstat/">sites.temple.edu/compstat/</a></li>
#     </ul>
#     December 2016 - September 2018 &nbsp;&nbsp;&nbsp;&nbsp; Teaching Assistant, Temple University
#     <ul>
#         <li style="list-style-type: none;font-weight: normal;">Assignment: Chemistry for Engineers recitation & General Chemistry II laboratory</li>
#     </ul>
#     September 2018 - April 2019 &nbsp;&nbsp;&nbsp;&nbsp; Teaching Assistant, Temple University
#     <ul>
#         <li style="list-style-type: none;font-weight: normal;">Assignment: General Chemistry I recitation & laboratory</li>
#     </ul>
#     December 2016 - September 2018 &nbsp;&nbsp;&nbsp;&nbsp; Undergraduate Research, Temple University
#
# </h3>
#
# <hr style="height:2.5px">
#
# <!-- Publications -->
# <h3 style="align: left;font-size: 12pt;">Publications</h3>
#
# 1. <h6 style="align: left;font-size: 10pt;"> BICePs 2.0: new tools for Bayesian Inference of Conformational Populations from Theory and Experiment. Yunhui Ge*, Rob Raddi*, Vincent Voelz. In prep.</h6>
#
# <hr style="height:2.5px">
#
# <!-- Skills & Languages -->
# <h3 style="align: left;font-size: 12pt;">Skills & Languages</h3>
# <h6 style="align: left;font-size: 10pt;">Primary Programming Languages: Python, C++, Bash, Visual Basic for Applications (Microsoft Excel macros)</h6>
# <h6 style="align: left;font-size: 10pt;">Markup Languages: Markdown, HTML, LaTex</h6>
# <h6 style="align: left;font-size: 10pt;">Preferred Operating System: UNIX</h6>
# <h6 style="align: left;font-size: 10pt;">High performance computing platforms: Owlsnest computing clusters, Folding@home distributed computing platform</h6>
# <h6 style="align: left;font-size: 10pt;">Proficient with the following programs: LabView & AutoCAD (engineering software), Gromacs & OpenMM(molecular dynamics simulations), Chimera & VMD-Visual Molecular Dynamics (interactive molecular visualization), mMASS (Mass spectrometry data acquisition and processing), TopSpin (NMR data acquisition and processing)</h6>
#
#
# <hr style="height:2.5px">
#
# <!-- Honors & Awards -->
# <!--
# <h3 style="align: left;font-size: 12pt;">Honors & Awards</h3>
# <a href="images/THE.jpg" target="_blank">Teaching in Higher Education Certification</a>;
# <hr style="height:2.5px">
# -->
#
# <!-- Other Experience -->
# <h3 style="align: left;font-size: 12pt;"> Other Experience </h3>
#
# <h3 style="align: left;font-size: 10pt;">
#     December 2008 - September 2018 &nbsp;&nbsp;&nbsp;&nbsp; Janitor/Handyman, Lords & Ladies Salon and Medical Spa
#     <ul>
#         <li style="list-style-type: none;font-size: 10pt;font-weight: normal;">Responsible for the cleanliness of the floors each week </li>
#         <li style="list-style-type: none;font-size: 10pt;font-weight: normal;">Performed repairs and standard maintenance of beauty salon and apartment complex</li>
#     </ul>
#     August 2011 - March 2014 &nbsp;&nbsp;&nbsp;&nbsp; Detailer/Lot Attendant/Shuttle Driver, Peruzzi Nissan Buick GMC
#
# </h3>
